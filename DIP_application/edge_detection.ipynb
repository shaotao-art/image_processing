# %%
import sys
sys.path.append('./../DIP_py')
from basic_funcs import *
from edge import *

# %%
img=io.imread("./../pic/iguana.png",as_gray=True)
display_img(img)
img.shape
# Out:
# (310, 433)

# %%
g_f_5=guassian_kernel(1,5)
g_f_5.shape
# Out:
# (5, 5)

# %%
img_filted=convlution(img,g_f_5)
# Out:
# (314, 437)

# %%
display_img(img_filted)

# %%
canny_h=np.array([-0.5,0,0.5])
canny_h=canny_h.reshape((1,-1))
canny_v=np.array([[0.5],[0],[-0.5]])

dx=convlution(img_filted,canny_h)
dy=convlution(img_filted,canny_v)
# Out:
# (310, 435)
# (312, 433)

# %%
plt.subplot(1,2,1)
display_img(dx)
plt.subplot(1,2,2)
display_img(dy)

# %%
mag=np.sqrt(dx**2+dy**2)
display_img(mag)

# %%
theta=np.arctan2(dx,dy)*180/np.pi%360

# %%
img_supp=non_maximum_suppression(mag,theta)

# %%
plt.imshow(img_supp,cmap="gray")

# %%
plt.imshow(img_supp>0.06,cmap="gray")

# %%
s,w=double_threshold(img_supp,0.05,0.04)

# %%
res=edge_Linking(img_supp,s,w)

# %%
plt.imshow(res)
