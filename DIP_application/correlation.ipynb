# %%
import sys
sys.path.append('./../DIP_py')
from basic_funcs import *

# %%
img_shelf=read_img("./../pic/shelf.jpg")
img_t=read_img("./../pic/template.jpg")
img_t=resize(img_t,(img_t.shape[0]+1,img_t.shape[1],img_t.shape[2]))
# img_t=img_t.astype(np.float32)/255
plt.subplot(1,2,1)
display_img(img_shelf)
plt.subplot(1,2,2)
display_img(img_t)
print(img_shelf.shape,img_t.shape)
# Out:
# (400, 1000, 3) (57, 39, 3)

# %% [markdown]
# ## 未归一化时不能够正确的匹配

# %%
img_cor=correlation(img_shelf,img_t)
io.imshow(img_cor,cmap="gray")
print(img_cor.shape)
# Out:
# (456, 1038, 3)
# (400, 1000)

# %%
idx=np.argwhere(img_cor==img_cor.max())
print(idx)
plt.imshow(img_shelf)
plt.plot(idx[0][1],idx[0][0],'bx',ms=40,mew=10)
plt.show()
# Out:
# [[101 544]]

# %% [markdown]
# ## 归一化后正确匹配

# %%
img_cor=normalized_correlation(img_shelf,img_t)
io.imshow(img_cor,cmap="gray")
print(img_cor.shape)
# Out:
# (400, 1000)

# %%
idx=np.argwhere(img_cor==img_cor.max())
plt.imshow(img_shelf)
plt.plot(idx[0][1],idx[0][0],'bx',ms=40,mew=10)
plt.show()
