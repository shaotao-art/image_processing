# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
def read_img_and_convert_to_gray(img_path):
    img=plt.imread(img_path)
    out= np.dot(img[...,:3], [0.2989, 0.5870, 0.1140])
    out=out.astype(int)
    return out

# %%
img = read_img_and_convert_to_gray('./pic/montain.jpg')
plt.imshow(img,cmap="gray")

# %%
np.array([1,2,3,4])

# %% [markdown]
# ### 图片基础操作
# 1. crop
# 2. dimmer
# 3. resize
# 4. rotate
# 5. grayscale

# %% [markdown]
# ### 重点
# 1. resize
# 2. rotate 旋转矩阵 计算出一个像素点的新坐标

# %% [markdown]
# ### question
# 1. 首先将图片除以255 浮点数的图片有什么意义
# 2. dim图片时 对数据的操作到底有什么意义
